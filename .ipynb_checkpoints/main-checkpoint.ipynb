# %%
import glob 
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.applications import VGG16
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import load_img, img_to_array, to_categorical
from tensorflow.keras import layers
from tensorflow.keras import applications
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping


tf.config.run_functions_eagerly(True)

# %%
# проверка

genuine = [glob.glob('Dataset_Signature_Final/Dataset/dataset1/real/*.*')]
img = plt.imread(genuine[0][0])

plt.imshow(img)

# %%
dataset_dir = os.path.abspath('Dataset_Signature_Final/Dataset')

IMAGE_SIZE = 200

images = []
labels = []

for dataset_folder in os.listdir(dataset_dir):
    dataset_path = os.path.join(dataset_dir, dataset_folder)
    if os.path.isdir(dataset_path):
        real_dir = os.path.join(dataset_path, 'real')
        forged_dir = os.path.join(dataset_path, 'forge')

        for image_path in os.listdir(real_dir):
            img = cv2.imread(os.path.join(real_dir, image_path))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (IMAGE_SIZE,IMAGE_SIZE))
            images.append(img_to_array(img))
            labels.append(0)  # genuine лейбл

        for image_path in os.listdir(forged_dir):
            img = cv2.imread(os.path.join(forged_dir, image_path))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (IMAGE_SIZE,IMAGE_SIZE))
            images.append(img_to_array(img))
            labels.append(1)  # forged лейбл

images = np.array(images) / 255.0  # Нормализация значений пикселей
labels = np.array(labels) # на выходе будет 0 - genuine, 1 - forged

print(len(images))
print(len(labels))
plt.imshow(images[20])
# Out:
# 720
# 720

# %%
earlyStopping = EarlyStopping(monitor='loss', min_delta=0, patience=4, verbose=1)
early_stop=[earlyStopping]

# %%
vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
for layer in vgg16.layers:
    layer.trainable = False

metrics = []

i = 1
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for train_index, test_index in kfold.split(images, labels):
    result = 0

    
    model = Sequential()
    data_augmentation = keras.Sequential([layers.experimental.preprocessing.RandomRotation(0.1)])
    model.add(vgg16)
    model.add(Flatten(input_shape=vgg16.output_shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))
    model.compile(
        loss='categorical_crossentropy', 
        optimizer=optimizers.Adam(learning_rate=1e-4), 
        metrics=[
            'accuracy', 
            'mean_absolute_percentage_error', 
            'mean_absolute_error', 
            'mean_squared_error'])
    

    # model.summary()

    x_train, x_test = images[train_index], images[test_index]
    y_train, y_test = labels[train_index], labels[test_index]

    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    result = model.fit(x_train, y_train, batch_size=32,epochs=10, callbacks=early_stop)
    i += 1
    model.save(f"CNN-fold-{i}.keras")

    metrics_fold = {
        "Train Accuracy" : result.history['accuracy'],
        "Train MAPE" : result.history['mean_absolute_percentage_error'],
        "Train MAE" : result.history['mean_absolute_error'],
        "Train MSE" : result.history['mean_squared_error'],
        "Train Loss" : result.history['loss'],
    }
    metrics.append(result.history)
# Out:
# Epoch 1/10
# c:\Users\minichazer\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 18/18 [==============================] - 113s 6s/step - loss: 0.8358 - accuracy: 0.5260 - mean_absolute_percentage_error: 240535040.0000 - mean_absolute_error: 0.4811 - mean_squared_error: 0.2981
# Epoch 2/10
# 18/18 [==============================] - 116s 6s/step - loss: 0.5603 - accuracy: 0.7205 - mean_absolute_percentage_error: 188900928.0000 - mean_absolute_error: 0.3778 - mean_squared_error: 0.1897
# Epoch 3/10
# 18/18 [==============================] - 118s 7s/step - loss: 0.3955 - accuracy: 0.8420 - mean_absolute_percentage_error: 147350784.0000 - mean_absolute_error: 0.2947 - mean_squared_error: 0.1232
# Epoch 4/10
# 18/18 [==============================] - 117s 7s/step - loss: 0.3008 - accuracy: 0.9028 - mean_absolute_percentage_error: 115594880.0000 - mean_absolute_error: 0.2312 - mean_squared_error: 0.0856
# Epoch 5/10
# 18/18 [==============================] - 114s 6s/step - loss: 0.2447 - accuracy: 0.9271 - mean_absolute_percentage_error: 95333144.0000 - mean_absolute_error: 0.1907 - mean_squared_error: 0.0670
# Epoch 6/10
# 18/18 [==============================] - 116s 6s/step - loss: 0.2005 - accuracy: 0.9479 - mean_absolute_percentage_error: 81212096.0000 - mean_absolute_error: 0.1624 - mean_squared_error: 0.0500
# Epoch 7/10
# 18/18 [==============================] - 116s 6s/step - loss: 0.1680 - accuracy: 0.9635 - mean_absolute_percentage_error: 68749224.0000 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0398
# Epoch 8/10
# 18/18 [==============================] - 117s 7s/step - loss: 0.1476 - accuracy: 0.9722 - mean_absolute_percentage_error: 61615696.0000 - mean_absolute_error: 0.1232 - mean_squared_error: 0.0338
# Epoch 9/10
# 18/18 [==============================] - 116s 6s/step - loss: 0.1170 - accuracy: 0.9861 - mean_absolute_percentage_error: 50170036.0000 - mean_absolute_error: 0.1003 - mean_squared_error: 0.0237
# Epoch 10/10
# 18/18 [==============================] - 116s 6s/step - loss: 0.1048 - accuracy: 0.9826 - mean_absolute_percentage_error: 44952976.0000 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0209
# Epoch 1/10
# 18/18 [==============================] - 119s 7s/step - loss: 0.8141 - accuracy: 0.5625 - mean_absolute_percentage_error: 232890048.0000 - mean_absolute_error: 0.4658 - mean_squared_error: 0.2855
# Epoch 2/10
# 18/18 [==============================] - 123s 7s/step - loss: 0.5578 - accuracy: 0.7049 - mean_absolute_percentage_error: 191328720.0000 - mean_absolute_error: 0.3827 - mean_squared_error: 0.1892
# Epoch 3/10
# 18/18 [==============================] - 120s 7s/step - loss: 0.4154 - accuracy: 0.8351 - mean_absolute_percentage_error: 155811136.0000 - mean_absolute_error: 0.3116 - mean_squared_error: 0.1287
# Epoch 4/10
# 18/18 [==============================] - 121s 7s/step - loss: 0.3347 - accuracy: 0.8872 - mean_absolute_percentage_error: 128555864.0000 - mean_absolute_error: 0.2571 - mean_squared_error: 0.0978
# Epoch 5/10
# 18/18 [==============================] - 126s 7s/step - loss: 0.2579 - accuracy: 0.9392 - mean_absolute_percentage_error: 102110728.0000 - mean_absolute_error: 0.2042 - mean_squared_error: 0.0687
# Epoch 6/10
# 18/18 [==============================] - 132s 7s/step - loss: 0.2096 - accuracy: 0.9583 - mean_absolute_percentage_error: 85966072.0000 - mean_absolute_error: 0.1719 - mean_squared_error: 0.0518
# Epoch 7/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1810 - accuracy: 0.9549 - mean_absolute_percentage_error: 73811032.0000 - mean_absolute_error: 0.1476 - mean_squared_error: 0.0440
# Epoch 8/10
# 18/18 [==============================] - 130s 7s/step - loss: 0.1606 - accuracy: 0.9722 - mean_absolute_percentage_error: 65986688.0000 - mean_absolute_error: 0.1320 - mean_squared_error: 0.0377
# Epoch 9/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1235 - accuracy: 0.9774 - mean_absolute_percentage_error: 52861768.0000 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0254
# Epoch 10/10
# 18/18 [==============================] - 126s 7s/step - loss: 0.1042 - accuracy: 0.9896 - mean_absolute_percentage_error: 45375904.0000 - mean_absolute_error: 0.0908 - mean_squared_error: 0.0197
# Epoch 1/10
# 18/18 [==============================] - 129s 7s/step - loss: 0.8372 - accuracy: 0.5503 - mean_absolute_percentage_error: 237264160.0000 - mean_absolute_error: 0.4745 - mean_squared_error: 0.2924
# Epoch 2/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.4967 - accuracy: 0.7708 - mean_absolute_percentage_error: 176111648.0000 - mean_absolute_error: 0.3522 - mean_squared_error: 0.1618
# Epoch 3/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.3812 - accuracy: 0.8646 - mean_absolute_percentage_error: 143085840.0000 - mean_absolute_error: 0.2862 - mean_squared_error: 0.1143
# Epoch 4/10
# 18/18 [==============================] - 127s 7s/step - loss: 0.2979 - accuracy: 0.9167 - mean_absolute_percentage_error: 115881584.0000 - mean_absolute_error: 0.2318 - mean_squared_error: 0.0833
# Epoch 5/10
# 18/18 [==============================] - 129s 7s/step - loss: 0.2387 - accuracy: 0.9375 - mean_absolute_percentage_error: 95581336.0000 - mean_absolute_error: 0.1912 - mean_squared_error: 0.0629
# Epoch 6/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1841 - accuracy: 0.9566 - mean_absolute_percentage_error: 75098096.0000 - mean_absolute_error: 0.1502 - mean_squared_error: 0.0448
# Epoch 7/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1584 - accuracy: 0.9774 - mean_absolute_percentage_error: 66290212.0000 - mean_absolute_error: 0.1326 - mean_squared_error: 0.0356
# Epoch 8/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1420 - accuracy: 0.9757 - mean_absolute_percentage_error: 59591664.0000 - mean_absolute_error: 0.1192 - mean_squared_error: 0.0312
# Epoch 9/10
# 18/18 [==============================] - 128s 7s/step - loss: 0.1038 - accuracy: 0.9844 - mean_absolute_percentage_error: 44485200.0000 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0206
# Epoch 10/10
# 18/18 [==============================] - 128s 7s/step - loss: 0.1045 - accuracy: 0.9826 - mean_absolute_percentage_error: 44032832.0000 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0215
# Epoch 1/10
# 18/18 [==============================] - 132s 7s/step - loss: 0.7594 - accuracy: 0.5660 - mean_absolute_percentage_error: 230613920.0000 - mean_absolute_error: 0.4612 - mean_squared_error: 0.2693
# Epoch 2/10
# 18/18 [==============================] - 132s 7s/step - loss: 0.5124 - accuracy: 0.7309 - mean_absolute_percentage_error: 180843872.0000 - mean_absolute_error: 0.3617 - mean_squared_error: 0.1696
# Epoch 3/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.4177 - accuracy: 0.8229 - mean_absolute_percentage_error: 152107664.0000 - mean_absolute_error: 0.3042 - mean_squared_error: 0.1308
# Epoch 4/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.3586 - accuracy: 0.8472 - mean_absolute_percentage_error: 130571920.0000 - mean_absolute_error: 0.2611 - mean_squared_error: 0.1107
# Epoch 5/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.2666 - accuracy: 0.9201 - mean_absolute_percentage_error: 102964808.0000 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0727
# Epoch 6/10
# 18/18 [==============================] - 124s 7s/step - loss: 0.2172 - accuracy: 0.9375 - mean_absolute_percentage_error: 86579648.0000 - mean_absolute_error: 0.1732 - mean_squared_error: 0.0560
# Epoch 7/10
# 18/18 [==============================] - 125s 7s/step - loss: 0.1784 - accuracy: 0.9618 - mean_absolute_percentage_error: 72036808.0000 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0432
# Epoch 8/10
# 18/18 [==============================] - 128s 7s/step - loss: 0.1456 - accuracy: 0.9757 - mean_absolute_percentage_error: 61171184.0000 - mean_absolute_error: 0.1223 - mean_squared_error: 0.0320
# Epoch 9/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1287 - accuracy: 0.9844 - mean_absolute_percentage_error: 55014060.0000 - mean_absolute_error: 0.1100 - mean_squared_error: 0.0267
# Epoch 10/10
# 18/18 [==============================] - 127s 7s/step - loss: 0.1012 - accuracy: 0.9844 - mean_absolute_percentage_error: 43870636.0000 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0191
# Epoch 1/10
# 18/18 [==============================] - 129s 7s/step - loss: 0.8810 - accuracy: 0.5104 - mean_absolute_percentage_error: 246192528.0000 - mean_absolute_error: 0.4924 - mean_squared_error: 0.3099
# Epoch 2/10
# 18/18 [==============================] - 127s 7s/step - loss: 0.5612 - accuracy: 0.7118 - mean_absolute_percentage_error: 195134592.0000 - mean_absolute_error: 0.3903 - mean_squared_error: 0.1895
# Epoch 3/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.4182 - accuracy: 0.8524 - mean_absolute_percentage_error: 157310896.0000 - mean_absolute_error: 0.3146 - mean_squared_error: 0.1287
# Epoch 4/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.3441 - accuracy: 0.8802 - mean_absolute_percentage_error: 133129928.0000 - mean_absolute_error: 0.2663 - mean_squared_error: 0.1001
# Epoch 5/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.2662 - accuracy: 0.9358 - mean_absolute_percentage_error: 106001480.0000 - mean_absolute_error: 0.2120 - mean_squared_error: 0.0706
# Epoch 6/10
# 18/18 [==============================] - 127s 7s/step - loss: 0.2088 - accuracy: 0.9601 - mean_absolute_percentage_error: 86737768.0000 - mean_absolute_error: 0.1735 - mean_squared_error: 0.0504
# Epoch 7/10
# 18/18 [==============================] - 129s 7s/step - loss: 0.1835 - accuracy: 0.9618 - mean_absolute_percentage_error: 75899632.0000 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0439
# Epoch 8/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1469 - accuracy: 0.9740 - mean_absolute_percentage_error: 62163120.0000 - mean_absolute_error: 0.1243 - mean_squared_error: 0.0320
# Epoch 9/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1392 - accuracy: 0.9792 - mean_absolute_percentage_error: 57260040.0000 - mean_absolute_error: 0.1145 - mean_squared_error: 0.0303
# Epoch 10/10
# 18/18 [==============================] - 131s 7s/step - loss: 0.1176 - accuracy: 0.9844 - mean_absolute_percentage_error: 49883812.0000 - mean_absolute_error: 0.0998 - mean_squared_error: 0.0242

# %%
metrics_avg = {
    'loss': 0,
    'accuracy': 0,
    'mean_absolute_percentage_error': 0,
    'mean_absolute_error': 0,
    'mean_squared_error': 0,

}
for i in range(5):
    
    model_fold = keras.models.load_model(f'CNN-fold-{i+1}.keras')
    evaluation = model_fold.evaluate(x_test, y_test, batch_size=32)
    metric_names = model.metrics_names
    print(f"Результат тестовой выборки фолда №{i+1}:")
    for metric, result in zip(metric_names, evaluation):
        print(f"{metric}: {result}")
        metrics_avg[metric] += (result / 5)

metrics_avg
# Out:
# c:\Users\minichazer\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 5/5 [==============================] - 8s 2s/step - loss: 0.0777 - accuracy: 0.9931 - mean_absolute_percentage_error: 35031100.0000 - mean_absolute_error: 0.0701 - mean_squared_error: 0.0120
# Результат тестовой выборки фолда №1:
# loss: 0.07771200686693192
# accuracy: 0.9930555820465088
# mean_absolute_percentage_error: 35031100.0
# mean_absolute_error: 0.07006220519542694
# mean_squared_error: 0.012005070224404335
# 5/5 [==============================] - 9s 2s/step - loss: 0.0931 - accuracy: 0.9792 - mean_absolute_percentage_error: 39986824.0000 - mean_absolute_error: 0.0800 - mean_squared_error: 0.0185
# Результат тестовой выборки фолда №2:
# loss: 0.09308066964149475
# accuracy: 0.9791666865348816
# mean_absolute_percentage_error: 39986824.0
# mean_absolute_error: 0.07997364550828934
# mean_squared_error: 0.018519889563322067
# 5/5 [==============================] - 10s 2s/step - loss: 0.0737 - accuracy: 1.0000 - mean_absolute_percentage_error: 33532842.0000 - mean_absolute_error: 0.0671 - mean_squared_error: 0.0107
# Результат тестовой выборки фолда №3:
# loss: 0.07372298836708069
# accuracy: 1.0
# mean_absolute_percentage_error: 33532842.0
# mean_absolute_error: 0.06706568598747253
# mean_squared_error: 0.010713893920183182
# 5/5 [==============================] - 10s 2s/step - loss: 0.0796 - accuracy: 1.0000 - mean_absolute_percentage_error: 36119640.0000 - mean_absolute_error: 0.0722 - mean_squared_error: 0.0117
# Результат тестовой выборки фолда №4:
# loss: 0.07955701649188995
# accuracy: 1.0
# mean_absolute_percentage_error: 36119640.0
# mean_absolute_error: 0.07223929464817047
# mean_squared_error: 0.011746144853532314
# 5/5 [==============================] - 10s 2s/step - loss: 0.1670 - accuracy: 0.9583 - mean_absolute_percentage_error: 66606328.0000 - mean_absolute_error: 0.1332 - mean_squared_error: 0.0417
# Результат тестовой выборки фолда №5:
# loss: 0.16704994440078735
# accuracy: 0.9583333134651184
# mean_absolute_percentage_error: 66606328.0
# mean_absolute_error: 0.1332126408815384
# mean_squared_error: 0.0416790172457695
# {'loss': 0.09822452515363694,
#  'accuracy': 0.9861111164093017,
#  'mean_absolute_percentage_error': 42255346.800000004,
#  'mean_absolute_error': 0.08451069444417954,
#  'mean_squared_error': 0.01893280316144228}

# %%
import json
json_obj = json.dumps(metrics)
with open('metrics.json', 'w', encoding='utf-8') as f:
    f.write(json_obj)

# %%
epochs = range(1, 11)
plt.figure(figsize=(12, 6))


plt.plot(epochs, metrics[0]['accuracy'], 'b', label='CNN-fold1')
plt.plot(epochs, metrics[1]['accuracy'], 'g', label='CNN-fold2')
plt.plot(epochs, metrics[2]['accuracy'], 'r', label='CNN-fold3')
plt.plot(epochs, metrics[3]['accuracy'], 'c', label='CNN-fold4')
plt.plot(epochs, metrics[4]['accuracy'], 'm', label='CNN-fold5')
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.yticks(np.arange(0, 1.0, 0.05))
plt.xlabel('Эпохи')
plt.ylabel('Точность')
plt.grid(alpha=0.3)
plt.title('Сравнение точности для 5 фолдов')
plt.legend()
plt.show()

# %%
epochs = range(1, 11)
plt.figure(figsize=(12, 6))
plt.plot(epochs, metrics[0]['mean_absolute_percentage_error'], 'b', label='CNN-fold1')
plt.plot(epochs, metrics[1]['mean_absolute_percentage_error'], 'g', label='CNN-fold2')
plt.plot(epochs, metrics[2]['mean_absolute_percentage_error'], 'r', label='CNN-fold3')
plt.plot(epochs, metrics[3]['mean_absolute_percentage_error'], 'c', label='CNN-fold4')
plt.plot(epochs, metrics[4]['mean_absolute_percentage_error'], 'm', label='CNN-fold5')
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.yticks(np.arange(0, 300000000, 7500000))
plt.xlabel('Эпохи')
plt.ylabel('MAPE')
plt.grid(alpha=0.3)
plt.title('Графики MAPE')
plt.legend()
plt.show()

# %%
epochs = range(1, 11)
plt.figure(figsize=(12, 6))
plt.plot(epochs, metrics[0]['mean_absolute_error'], 'b', label='CNN-fold1')
plt.plot(epochs, metrics[1]['mean_absolute_error'], 'g', label='CNN-fold2')
plt.plot(epochs, metrics[2]['mean_absolute_error'], 'r', label='CNN-fold3')
plt.plot(epochs, metrics[3]['mean_absolute_error'], 'c', label='CNN-fold4')
plt.plot(epochs, metrics[4]['mean_absolute_error'], 'm', label='CNN-fold5')
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.yticks(np.arange(0, 0.8, 0.05))
plt.xlabel('Эпохи')
plt.ylabel('MAE')
plt.grid(alpha=0.3)
plt.title('Графики MAE')
plt.legend()
plt.show()

# %%
epochs = range(1, 11)
plt.figure(figsize=(12, 6))
plt.plot(epochs, metrics[0]['mean_squared_error'], 'b', label='CNN-fold1')
plt.plot(epochs, metrics[1]['mean_squared_error'], 'g', label='CNN-fold2')
plt.plot(epochs, metrics[2]['mean_squared_error'], 'r', label='CNN-fold3')
plt.plot(epochs, metrics[3]['mean_squared_error'], 'c', label='CNN-fold4')
plt.plot(epochs, metrics[4]['mean_squared_error'], 'm', label='CNN-fold5')
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.yticks(np.arange(0, 0.4, 0.025))
plt.xlabel('Эпохи')
plt.ylabel('MSE')
plt.grid(alpha=0.3)
plt.title('Графики MSE')
plt.legend()
plt.show()

# %%
epochs = range(1, 11)
plt.figure(figsize=(12, 6))
plt.plot(epochs, metrics[0]['loss'], 'b', label='CNN-fold1')
plt.plot(epochs, metrics[1]['loss'], 'g', label='CNN-fold2')
plt.plot(epochs, metrics[2]['loss'], 'r', label='CNN-fold3')
plt.plot(epochs, metrics[3]['loss'], 'c', label='CNN-fold4')
plt.plot(epochs, metrics[4]['loss'], 'm', label='CNN-fold5')
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.xticks(np.arange(min(epochs), max(epochs)+1, 1))
plt.yticks(np.arange(0, 1, 0.05))
plt.xlabel('Эпохи')
plt.ylabel('Loss')
plt.grid(alpha=0.3)
plt.title('Графики Loss')
plt.legend()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 6, 6, 512)         14714688
#
#  flatten_8 (Flatten)         (None, 18432)             0
#
#  dense_16 (Dense)            (None, 256)               4718848
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_17 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 19,434,050
# Trainable params: 4,719,362
# Non-trainable params: 14,714,688
# _________________________________________________________________
